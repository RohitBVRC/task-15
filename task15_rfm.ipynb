# %% [markdown]
# # Task 15 – RFM Customer Segmentation

# %%
import pandas as pd
import numpy as np

# %%
# Load dataset
# Perform RFM calculation

# %%
# Create RFM scores and assign segments

# %%
# Export segmentation results
